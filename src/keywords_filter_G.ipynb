# %%
import pandas as pd
import os
import re

DATA_FILE = '../processed/microblogs_clean.csv'

def analyze_crime_blogs():
    if not os.path.exists(DATA_FILE):
        print(f"❌ Không tìm thấy file {DATA_FILE}")
        return

    print(f"👮 Đang rà soát AN NINH & TỘI PHẠM (Phiên bản High-Precision)...")
    print(f"Mục tiêu: Loại bỏ tin thể thao/giải trí, tập trung vào hành vi thực tế.")

    # 1) Đọc dữ liệu (SỬA: thêm 'ID')
    try:
        df = pd.read_csv(DATA_FILE, usecols=['ID', 'timestamp', 'text_clean', 'Location'])
        df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')
    except Exception as e:
        print(f"❌ Lỗi đọc file: {e}")
        return

    # 2) Lọc thời gian (Ngày 12,13,14,15 tháng 5)
    mask_days = (df['timestamp'].dt.day.isin([12, 13, 14, 15])) & (df['timestamp'].dt.month == 5)
    df_subset = df.loc[mask_days].copy()
    if df_subset.empty:
        print("✅ Không có bản ghi trong khoảng thời gian yêu cầu.")
        return

    df_subset['text_lower'] = df_subset['text_clean'].fillna('').str.lower()

    COVERT_KEYWORDS = {
        '1. Tội phạm Đường phố (Street Crime)': [
            "stole my", "robbed at", "thief", "breaking into", "break in",
            "burglar", "mugged", "pickpocket", "shoplift",
            "gunshot", "stabbed", "shooting at", "murdered", "homicide",
            "dead body", "corpse", "beaten up",
            "police chase", "arrested for", "handcuffed", "sirens wailing",
            "cop car", "police raid", "swat team"
        ],
        '2. Khủng bố & Nổ (Terror & Explosives)': [
            "bomb threat", "bombing", "suicide bomber", "improvised explosive",
            "detonated", "explosion heard", "loud blast", "shrapnel",
            "hostage situation", "terrorist attack", "hijacked",
            "suspicious device", "found a bomb", "grenade"
        ],
        '3. Vũ khí Sinh/Hóa học (Bio-Chemical)': [
            "gas leak", "nerve gas", "sarin", "anthrax", "ricin",
            "mustard gas", "biohazard", "hazmat suit", "decontamination",
            "chemical smell", "smell of gas", "strange fog", "yellow smoke",
            "eyes burning", "skin blistering", "choking on smoke"
        ],
        '4. Hoạt động Khả nghi (Suspicious Ops)': [
            "black van", "white van", "unmarked car", "suspicious truck",
            "getaway car", "speeding away", "license plate",
            "unattended bag", "suspicious package", "left a bag", "dropped a bag",
            "stalking me", "following me", "spying on", "looking in windows",
            "wearing a mask"
        ]
    }

    NOISE_KEYWORDS = [
        'movie', 'film', 'cinema', 'watch', 'episode', 'series', 'season', 'tv show',
        'trailer', 'spoiler', 'actor', 'actress', 'director', 'hollywood', 'dvd',
        'masterchef', 'true blood', 'vampire', 'zombie', 'fiction', 'novel',
        'game', 'play', 'xbox', 'ps3', 'wii', 'nintendo', 'console', 'download',
        'app', 'iphone', 'android', 'update', 'level', 'score', 'high score',
        'sport', 'match', 'win', 'won', 'lost', 'lose', 'defeat', 'championship',
        'league', 'tournament', 'cup', 'golf', 'shoot', 'shot', 'par', 'birdie',
        'basketball', 'football', 'soccer', 'hockey', 'ufc', 'fight', 'round',
        'song', 'music', 'band', 'concert', 'album', 'track', 'listen', 'radio',
        'dj', 'remix', 'singer', 'ticket', 'tour', 'video', 'youtube',
        'twitter jail', 'kill time', 'killing me', 'stole my heart', 'shoot me',
        'photo shoot', 'snapshot', 'bomb food', 'da bomb', 'blow up my phone',
        'burn calories', 'sun burn', 'hair cut', 'bag of', 'shopping bag'
    ]

    # 3) Compile regex an toàn (SỬA: escape keyword)
    def make_pat(phrases):
        escaped = [re.escape(p) for p in phrases]
        return re.compile("|".join(escaped), flags=re.IGNORECASE)

    noise_re = make_pat(NOISE_KEYWORDS)

    for group_name, keywords in COVERT_KEYWORDS.items():
        print(f"\n--- 🔍 Rà soát nhóm: {group_name.upper()} ---")

        target_re = make_pat(keywords)

        matched = df_subset[df_subset['text_lower'].str.contains(target_re, na=False)]
        clean_matched = matched[~matched['text_lower'].str.contains(noise_re, na=False)]
        clean_matched = clean_matched.sort_values('timestamp')

        if clean_matched.empty:
            print("   (Không tìm thấy dấu hiệu đáng ngờ sau khi lọc kỹ)")
            continue

        print(f"   ⚠️ Tìm thấy {len(clean_matched)} tin tiềm năng:")

        for _, row in clean_matched.iterrows():
            id_str = str(row.get('ID', '')).strip()
            time_str = row['timestamp'].strftime('%d/%m %H:%M') if pd.notna(row['timestamp']) else "NA"
            loc_str = str(row.get('Location', '')).replace('POINT', '').replace('(', '').replace(')', '').strip()
            text = row.get('text_clean', '')
            print(f"{id_str}|{time_str:<10} | {loc_str:<20} | {text}")

    print("✅ HOÀN TẤT RÀ SOÁT.")

if __name__ == "__main__":
    analyze_crime_blogs()
# Out:
# 👮 Đang rà soát AN NINH & TỘI PHẠM (Phiên bản High-Precision)...
# Mục tiêu: Loại bỏ tin thể thao/giải trí, tập trung vào hành vi thực tế.
#
# --- 🔍 Rà soát nhóm: 1. TỘI PHẠM ĐƯỜNG PHỐ (STREET CRIME) ---
#    ⚠️ Tìm thấy 108 tin tiềm năng:
# 11799|12/05 01:14 | 42.24071 93.36002    | my last tweet fails cause it made no sense what so ever. all i know is that i want to go to go to the beach for spring break in a yea
# 8577|12/05 02:12 | 42.16818 93.46546    | why does it take 3 cop cars to pull someone over for speeding on speer?
# 4850|12/05 03:55 | 42.23334 93.33166    | walking to god know's where?! good thing alex's and mark's dad is with us. don't feel like getting mugged again.
# 118971|12/05 04:08 | 42.26105 93.46027    | hugh hefner is 84 has a 24 year old girlfriend she says age don't matter sixty year difference like sleeping with a corpse? ugh.
# 165475|12/05 05:07 | 42.23098 93.35003    | haha.. i remember when twitter stole my picture... but they let me upload a new one.
# 140106|12/05 10:22 | 42.25928 93.39077    | there's a police chase outside the guardian. first a fire alarm now this. life can't get more exciting. can it?
# 91664|12/05 11:31 | 42.19737 93.44988    | suspected auto thief rams two police cars injures officer
# 40995|12/05 12:48 | 42.27167 93.47265    | getting news that many protesters are getting arrested for isa gathering. where is our right to protest peacefully?
# 152524|12/05 13:31 | 42.23894 93.32447    | mmmkay there's like 3 cop cars an ambulance and a fire truck in front of my building. i hope everybody okay.
# 120464|12/05 13:35 | 42.21181 93.3688     | justt stole 2 cop cars and ran over a couple ilove gta (:
# 127751|12/05 13:39 | 42.16316 93.29731    | crotch-rocket fire truck and two cop cars on broadway onramp to 794. woman crying...??
# 122722|12/05 16:21 | 42.22331 93.39157    | 35 236 000 murdered: the communist chinese #tcot #ocra #sgp #p2 #tlot #phnm
# 155103|12/05 17:30 | 42.27963 93.42871    | im expecting my bruises to shine in the morning :/ people will think ive been beaten up :l:l ahhhhh crap.....
# 50451|12/05 17:43 | 42.21329 93.35722    | love is like a brick. you can build a house or you can sink a dead body
# 25452|12/05 17:52 | 42.2127 93.33405     | day two without #newtwitter cars overturned in road burned out corpses begging children for food it is a catastrophe
# 177877|12/05 18:54 | 42.22243 93.27973    | to whomever found/stole my #starbucks card & used it thanks for the extra star. however next time ask me please.
# 18660|12/05 19:22 | 42.2354 93.32646     | we'll go for spring break instead.
# 81033|12/05 19:31 | 42.23186 93.36041    | procrastination is the thief of time...
# 100609|12/05 19:59 | 42.21771 93.47984    | civil defence vehicles with a cop car across my house fire or somethang. my brother got excited and goes down to look kpo only.
# 84909|12/05 20:06 | 42.21977 93.46866    | so my ex boyfriend who is a police officer jus came on the block in his cop car...the dudes on the block went in on me saying im a sell
# 120173|12/05 20:48 | 42.22361 93.33565    | letters; lives: car thief
# 129103|12/05 21:38 | 42.22479 93.30809    | uhh either my dad is home or someone is trying to break into my house
# 114867|12/05 21:52 | 42.2581 93.24698     | to have your mother brother and nephew all murdered is just horrible #jenniferhudson
# 144342|12/05 21:57 | 42.1894 93.36681     | i can't sleep! my friends body is just now being removed from the house & the investigators are treating this like a arson & homicide ca
# 65771|12/05 22:02 | 42.24601 93.32327    | my goal in life is to get a codis hit and an afis hit from burglaries of my property. one down one to go.
# 14572|12/05 22:03 | 42.264 93.38997      | this is for every time you've stabbed me in the back; and for every notch in your bedpost.
# 85759|12/05 22:31 | 42.22184 93.19666    | i've seen like 20 cop cars in 10mins
# 162061|12/05 22:37 | 42.20238 93.34244    | is raping a prostitute shoplifting?
# 4167|12/05 22:38 | 42.21417 93.32287    | loves how my brother stole my saturday night. and is still working on it. i guess goodnight :/
# 138015|13/05 00:01 | 42.19795 93.52497    | someone stole my algebra 2 textbook. everything they open it they look and see my name and i bet they just laugh and laugh
# 20627|13/05 01:15 | 42.22125 93.33605    | driven 1/2 a mile and passed by 4 cop cars. fair warning not to speed up going to work
# 125584|13/05 01:33 | 42.21329 93.46306    | with all of the problems i have now my heart is breaking into pieces
# 24763|13/05 01:46 | 42.24395 93.35642    | only takes three cop cars to pull you over for driving down a one way sober!
# 162262|13/05 02:01 | 42.18469 93.32846    | just got warpaint's ep exquisite corpse and dum dum girls 'i will be'..both excellent...e.c is beautiful not grisly like title suggests
# 69256|13/05 02:07 | 42.16641 93.44429    | fire alarm! this is not a drill! nice break in the sunshine :)
# 177538|13/05 02:17 | 42.25515 93.42113    | who the f*ck stole my... nvrm i found it.
# 47315|13/05 02:37 | 42.29496 93.32966    | the security machine almost stole my wedding ring and forgot to put my liquids in a clear pouch... t5 security much calmer than cph was
# 160466|13/05 07:41 | 42.23776 93.35682    | afstandsbediening is gethiefd
# 119929|13/05 08:05 | 42.17673 93.35083    | i still get butterflies when i see cop cars even tho i'm legit now y
# 144898|13/05 09:55 | 42.22302 93.38198    | the twisted tea thief just confessed. he is on a payment plan.
# 121576|13/05 09:59 | 42.2528 93.44269     | bella is something else...does anyone else have a dog that is a thief?
# 170020|13/05 12:45 | 42.23864 93.35163    | dear friends. i got stabbed by another rose today. all i can think about is flesh eating bacteria. (don't wiki or google it. seriously.
# 20171|13/05 12:47 | 42.29879 93.51299    | there's always a break inside the fire
# 130946|13/05 14:20 | 42.20592 93.37559    | it looks like a good time to get into $rig (transocean) this stock has been beaten up as bad as $bp but by association only earnings 8
# 86069|13/05 15:03 | 42.22655 93.36002    | there's like 3 ablulances 4 cop cars and 1 fire truck...i hope everyone is ok
# 154028|13/05 15:04 | 42.21771 93.37559    | oh my jesus. mad carpool chase in the middle of no where? i've never seen so many cop cars in the middle of bfe.
# 25818|13/05 15:04 | 42.23864 93.48863    | how do i break into a field...and can you help me...?
# 69080|13/05 15:06 | 42.22538 93.33166    | so who is counting down to lindsay's jailbreak in less than 2 hours?
# 69861|13/05 15:20 | 42.28759 93.55533    | i would rather siphon gas out of a cop car than get gas from bp
# 112967|13/05 17:27 | 42.2298 93.25657     | so basically i stole my frnds phone 2 tweet!!i'm i dat addicted???
# 136982|13/05 18:44 | 42.22567 93.38198    | blue cop cars here.. thts weird
# 147905|13/05 19:32 | 42.21535 93.35522    | bad management with no auditing. but this lady is still a big thief like any other thief and must go to jail.
# 26247|13/05 20:10 | 42.21034 93.27214    | two cop cars off to the side of the road was the reason for all of that traffic..this is a fcking joke smh
# 177699|13/05 21:12 | 42.22921 93.37839    | you know its going to be a fun day at work when you pull up to the mart and there are two cop cars a firetruck and an ambulance. #tgif
# 144570|13/05 21:39 | 42.16434 93.54894    | open my back door to let my dog in and saw five cop cars all up and down my block. i didn't hear any sirens #wtf
# 144240|13/05 21:50 | 42.20768 93.3708     | just saw on tv this guy i know is wanted for burglary and they're offering a cash reward
# 72437|13/05 23:46 | 42.21152 93.38837    | woah something is going on in my neighborhood cop cars going by a cop chopper hovering by still here. i'm worried.
# 126216|14/05 00:54 | 42.18764 93.36121    | somethin sussy is goin on boro a thousand cop cars 8 emts 40 ambulances
# 169912|14/05 01:08 | 42.29083 93.2326     | when a black man is murdered it is 'regrettable.' when a cop is murdered it is a national travesty #oscargrant
# 6373|14/05 02:05 | 42.22361 93.55852    | 6 cop cars an ambulance and a fire truck? totally unnecessary.
# 126614|14/05 02:44 | 42.23687 93.34963    | ok- i feel it is time to wheel my corpse upstairs to the bedroom. tomorrow is back to school day for me! i gotta get up at 5:30 am!!
# 127370|14/05 04:40 | 42.17171 93.33485    | i wish my dog didnt use the same bark for everything. i never know if someone is breaking into the house..or if he sees a fly.
# 48643|14/05 05:01 | 42.28375 93.41873    | raj thackeray blames 'migrants' for malaria outbreak in mumbai city...never seen such a brainless leader...worse is ppl still follow him
# 142363|14/05 05:30 | 42.26017 93.45268    | looks like somethings going on down the block... 2 cop cars and a ghost car.
# 173714|14/05 06:19 | 42.20444 93.38198    | the only thing i hate more than a thief is a cripple thief.
# 45562|14/05 12:47 | 42.23304 93.50979    | why is lisa simpson in the top 10 trending worldwide on twitter? did she od get knocked-up get caught shoplifting?
# 86329|14/05 16:01 | 42.26429 93.503      | a thief steals someone else's identity & tricks u into falling in love with him all the while a pedophile is trying 2 wife u #aladdin
# 96060|14/05 16:20 | 42.28582 93.44469    | :o the thief is the pink version of pnutz #ggtv
# 29457|14/05 16:23 | 42.21948 93.36241    | looks like the police are gonna get someone. 3 cop cars flew by.
# 21775|14/05 16:27 | 42.27285 93.29731    | arnold: story about cows not breaking into fence #ldsconf
# 169321|14/05 16:35 | 42.2926 93.49382     | 'mugged by two snails'
# 111689|14/05 16:42 | 42.17555 93.54374    | our family is thicker than thiefs so go ahead and try and mess with us. :)
# 28367|14/05 17:26 | 42.2068 93.3708      | reasons i don't like the gypsies 1. they stole my garden. 2. vandalised our car twice. 3. set fire to cars. 4. think they are above the
# 29238|14/05 17:37 | 42.24218 93.33805    | so... someone got stabbed right outside of target! i'm a bit confused as to why the ambulance is in the middle of the street though!
# 68621|14/05 17:57 | 42.28258 93.42672    | i dont know what i think of hurricane..the only thing i can say is i almost had a heartattack when shannon got stabbed did'nt expect tha
# 119876|14/05 18:14 | 42.21447 93.36281    | i admire someone absorbed something in my age i am like the dead corpse with no passion and interest. what should i do to return my fir
# 147921|14/05 18:26 | 42.22685 93.37679    | there's gotta be something going on - 7 cop cars between my office building and the conrad hilton next door
# 94756|14/05 18:53 | 42.22567 93.28972    | breaking into the smartphone (risks included)
# 131881|14/05 20:29 | 42.24513 93.31967    | in court...no charges filed in the dibble triple homicide house fire.
# 158098|14/05 20:48 | 42.21447 93.19785    | ilford is mad u know! just witnessed a police chase ahahahahah
# 81458|14/05 21:38 | 42.20267 93.38278    | i hope with the #newtwitter they murdered that big ass whale.
# 28858|14/05 22:42 | 42.22596 93.34324    | the plant is commonly known as the 'corpse flower ' because upon blooming it emits a smell similar to rotting flesh.
# 15088|14/05 23:16 | 42.27285 93.22981    | don't know why but u're stabbed deep inside my heart already..it doesn't need reasons to love. :) all i know is just i love you!
# 168588|14/05 23:30 | 42.26901 93.52617    | omg i hate people who break in to cars
# 170720|15/05 00:29 | 42.26901 93.31728    | i think someone is trying to break in my neighbour's house... ok. this is efing scary ok.
# 93051|15/05 01:39 | 42.28375 93.44549    | whoever stole my pic took my tag off & put it on fotolog is a complete cow. brazilian as usual. i only want you to ask first for god sa
# 127382|15/05 02:47 | 42.29024 93.27654    | i stole my sister's koi bubble tea and finally realised how nice it is.
# 148551|15/05 04:05 | 42.2127 93.38438     | sitting at avondale bus stop waitn patiently when 3 cop cars start circling the area looking for 3 guys... & someones alarm just went of
# 36448|15/05 07:04 | 42.25014 93.41833    | where im from the dope boys is the rockstars. but they cant cop cars without seein cop cars.
# 106041|15/05 07:46 | 42.23658 93.50141    | flip what's with ak city 2nite on my way home i saw 2 cop cars 2 ambulances & 3 fire engines all with lights on and sirens blaring....
# 119929|15/05 08:04 | 42.25545 93.4407     | literally 10 cop cars all in a row. out to get someone.
# 77691|15/05 08:16 | 42.21093 93.36441    | did i see ken brown break into a jog coming down the 18th at the ladies british open on bbc.... is the bar open or what ?
# 77696|15/05 08:51 | 42.2413 93.45108     | the matrix: neo killed in clash with smith sentinels breached the crafts hull and what trinity is doing? a slimy kiss with corpses... e
# 173720|15/05 08:54 | 42.20385 93.21902    | debit card info stolen but citizens is already fixing it i love my bank i hate the thief
# 9083|15/05 10:21 | 42.27255 93.4407     | 8 cop cars circled my neighborhood this morning-looked a little like a charlie chaplin caper. #americasmostwantedstealingbackyardmangoes
# 83258|15/05 10:42 | 42.29643 93.52577    | two cop cars for a guy and a girl on a moped seemed a bit of overkill
# 145903|15/05 11:22 | 42.23216 93.35882    | wed 28/7 angmering. suspect cars followed after suspect burglary. overhead and cars stopped without incident. enqs continue.
# 131916|15/05 11:30 | 42.29437 93.42951    | i dont think anyone stole my phone. cos ... one it dropped in the snow and everytime i call it it rings. the thief wudve got pissed off
# 140064|15/05 13:16 | 42.21211 93.26775    | a conservative is a liberal that's been mugged
# 15587|15/05 16:17 | 42.20945 93.3684     | i stole my car jodie *in my best yvette voice* lmboo
# 10429|15/05 17:45 | 42.22361 93.34963    | #breakuplines my mommy told me i cant be wit you...because your uncle is a thief :(
# 138140|15/05 19:41 | 42.24071 93.35762    | 'i just want my wife's corpse ' survivor pleads
# 166535|15/05 20:36 | 42.21211 93.34564    | currents: security; perfect welcome for a burglar: siren camera and a call to police
# 9298|15/05 21:17 | 42.2124 93.38438     | is waiting for the swat team...
# 80547|15/05 21:24 | 42.22508 93.36521    | someone claiming he's the best is gonna get murdered on theeeeee turnnnnntabbbllleeessss!!!!!! bwahahahahahahahahha!
# 160269|15/05 21:43 | 42.20503 93.35602    | #yeg 8 cop cars just screamed by westbound on whitemud. something is def. going down.
# 136865|15/05 21:55 | 42.25663 93.44469    | nah but it's kinda stupid he was just stabbed in the neck pulled the pen out and then ran like a mile explain to me how he is still stan
# 4208|15/05 21:59 | 42.24041 93.28572    | the leading cause of death for black american boys is homicide
#
# --- 🔍 Rà soát nhóm: 2. KHỦNG BỐ & NỔ (TERROR & EXPLOSIVES) ---
#    ⚠️ Tìm thấy 25 tin tiềm năng:
# 60824|12/05 02:47 | 42.21889 93.46706    | more on afghanistan u.n. attack: 2 suicide bombers strike compound several insurgents still in building - police via reuters
# 120096|12/05 06:35 | 42.27255 93.40715    | there is a reason some of us call ourselves republican not conservative. conservative was hijacked long ago.
# 101280|12/05 10:33 | 42.1953 93.39157     | q.&amp;a.: rescuing a hijacked hotmail account
# 45559|12/05 13:19 | 42.27638 93.34604    | remember kids once you have pulled the pin mr. grenade is no longer your friend
# 80448|12/05 17:00 | 42.17053 93.47385    | bombings kill dozens near mosque in iran
# 166415|13/05 01:42 | 42.18616 93.36321    | ahmadinejad assassination attempt? grenade attack reported near iran leader's convoy
# 96752|13/05 07:52 | 42.22243 93.34204    | deadly bombings strike pakistani police
# 126367|13/05 08:30 | 42.25751 93.3041     | world briefing | europe; greece: five are charged in bombing
# 74611|13/05 19:51 | 42.20945 93.3724     | hostage situation is right across the st from our house. it's crazy seeing swat march down our st & hide in the dark. fully armed 2.
# 109363|13/05 20:51 | 42.26282 93.55972    | at home... and i swear i'm hearing grenades or something... wtf is going on?
# 103575|13/05 21:07 | 42.17614 93.24898    | suicide bomber strikes in northwest pakistan
# 129540|13/05 21:40 | 42.2239 93.35722     | one of the great tragedies of mankind is that morality has been hijacked by religion.' ~ arthur c. clarke via tamgo iheartquotes
# 175762|13/05 22:03 | 42.27815 93.33685    | soo what do y'all think is worse? hookin up w/ a landmine or grenade?
# 153047|14/05 09:58 | 42.25515 93.41953    | afghan spy agency accuses pakistan agency in suicide bombing
# 160200|14/05 12:22 | 42.2466 93.56052     | bombings hit atomic experts in iran streets
# 129117|14/05 13:37 | 42.21712 93.34484    | suicide bomber kills 21 at cafe in iraq's diyala province
# 135483|14/05 16:17 | 42.20709 93.38118    | new waitress at merlotte's = grenade!! #trueblood #jerseyshore
# 98413|14/05 21:30 | 42.21417 93.26575    | shes a land-mine and her friend is a grenade ahaha
# 63710|14/05 22:34 | 42.28228 93.31648    | is adding the words 'grenade' and 'landmine' to his regular vocabulary. #jerseyshore
# 119892|15/05 00:25 | 42.22154 93.26935    | world briefing | africa; somalia: suicide bomber attacks at presidential gates
# 34206|15/05 14:46 | 42.24159 93.32726    | terrorist attacks car crashes buildings on fire it's nuthing to me but this computer virus mite b the last straw
# 110904|15/05 17:32 | 42.18174 93.39756    | coordinated bombings aimed at shiites and sunnis alike strike baghdad
# 88200|15/05 19:49 | 42.2124 93.39916     | 4 accused of bombing plot at bronx synagogues
# 16266|15/05 20:44 | 42.23658 93.36002    | food aid program to resume after bombing in pakistan
# 21846|15/05 22:10 | 42.21388 93.32607    | one way to beat suicide bombers is to offer them a job as demolition experts pay them to legally blow buildings up
#
# --- 🔍 Rà soát nhóm: 3. VŨ KHÍ SINH/HÓA HỌC (BIO-CHEMICAL) ---
#    ⚠️ Tìm thấy 17 tin tiềm năng:
# 129289|12/05 01:22 | 42.23776 93.34204    | a house a few blocks from us exploded tonight. gas leak? we mistook it for fireworks. nobody was hurt but the damage is incredible. #fb
# 24505|12/05 02:52 | 42.19235 93.39516    | now there was only shaggydog rumbling at the small man his eyes burning like green fire
# 10549|12/05 03:41 | 42.16729 93.20145    | at least i like the smell of gasoline. i just hope no one sets me on fire.
# 15562|12/05 04:32 | 42.27992 93.54175    | i'm starting to think our 'pricing strategy' for the house resembles my pricing strategy for craigslist. aka how low can you go?
# 34020|12/05 19:39 | 42.18439 93.38398    | after 8 years f.b.i. shuts book on anthrax case
# 989|13/05 20:10 | 42.21004 93.3684     | observatory; finding a way to stop ricin in its deadly path
# 847|13/05 20:31 | 42.19117 93.39756    | gas leak at camosun lansdowne campus fire crews on scene
# 17752|13/05 23:15 | 42.17053 93.3692     | okay who all is suing bp for that gas leak???
# 103413|13/05 23:21 | 42.17761 93.35762    | no. this does not mean jimmy anderson is a good bowler. don't go overboard dear cricinfo.
# 47058|14/05 11:24 | 42.24071 93.35602    | honda announces pricing for 2011 odyssey
# 152922|14/05 13:36 | 42.17319 93.48982    | on top of strep... house flooded there has been a gas leak out of my fire place.... thank you jesus for the strength!
# 36488|14/05 21:57 | 42.22803 93.37799    | very productive tonight phping. eyes burning with the fire of a thousand acre blaze.
# 30982|15/05 02:25 | 42.21653 93.38997    | we're now a avg authorized reseller as such we can now offer competitive pricing on security software for home business and charity cli
# 27124|15/05 05:05 | 42.24336 93.32527    | a used car or a katrina biohazard?
# 106948|15/05 13:39 | 42.2298 93.48343     | chevy volt pricing: the war of the asterisk
# 138350|15/05 15:48 | 42.22891 93.35203    | oh my days our cat has done the smelliest poo ever in the world full stop *reaches for biohazard emegency button* oxygen nurse!
# 91826|15/05 22:35 | 42.29083 93.44629    | motorist group slams 'congestion pricing'
#
# --- 🔍 Rà soát nhóm: 4. HOẠT ĐỘNG KHẢ NGHI (SUSPICIOUS OPS) ---
#    ⚠️ Tìm thấy 20 tin tiềm năng:
# 26685|12/05 01:12 | 42.20739 93.37759    | the pigs r out tonight. they pulling folks over in unmarked cars. a tan impala 03 champagne. a olive taurus new black tint on both.
# 175342|12/05 12:06 | 42.20739 93.35642    | now i know why im scared upon leaving a city cab...im afraid the smoke monster is stalking me :/
# 154289|12/05 17:11 | 42.28228 93.41753    | jeffshaw i'm taping a flashlight to my head as we speak. that license plate is going to be on my wall yo.
# 104340|12/05 20:26 | 42.20533 93.34284    | i think someone is #twitterstalking me...oooo lol
# 14711|12/05 22:19 | 42.21358 93.35482    | what exactly is a suspicious package? if i were a terrorist i would make my bomb look ordinary. definitely not suspicious. these guys s
# 96014|13/05 02:25 | 42.22095 93.24179    | not good! - would the owner of a gmc safari license plate number xxxx please contact security at ext. 44444 and press 3?
# 78667|13/05 04:58 | 42.26518 93.19945    | realized that back to the future ii is sent 5 years from now. where r the flying cars & hoverboards? we do have orange license plates.
# 171206|13/05 13:19 | 42.20562 93.42712    | if i saw someone wearing a mask thing like adam is in the sky sailing photos i'd like hug them&take a photo. hahah xd
# 1016|13/05 22:27 | 42.16464 93.37       | just saw a white van full of asians. lol!
# 168661|13/05 23:53 | 42.19412 93.47944    | bho has not lowered unemployment. he made you buy his #hc increased ur taxes ignores the constitution is spying on u. want more? #tlo
# 140968|14/05 06:45 | 42.16729 93.42073    | same question as every week: what the heck is wrong with white van drivers? why the aggression??
# 11138|14/05 07:45 | 42.23569 93.33206    | we c a license plate that says we &lt;3 bp 1st thing i thought beer pong. charlie thought the oil company bp. we're so different lmao!
# 32360|14/05 12:41 | 42.23039 93.22142    | u.s. hunts for more suspicious packages
# 137808|14/05 15:06 | 42.26636 93.23859    | yo girl is stalking me!
# 41800|14/05 20:42 | 42.2354 93.34644     | i only saw 2 cars with the number 27 on their license plates. o:
# 141941|15/05 02:11 | 42.28375 93.46586    | for all hype about airport security tried twice to report unattended bag at iad to no avail
# 138013|15/05 11:00 | 42.2466 93.45068     | can feel multiple illnesses stalking me at once. not sure which is my favorite yet.
# 72031|15/05 18:56 | 42.17319 93.20544    | there can't be any justification for spying on the un secretary general! #cablegate #wikileaks
# 86641|15/05 20:13 | 42.28936 93.24618    | man 4 police unmarked cars was behind me! smh
# 103230|15/05 22:56 | 42.19412 93.32087    | lmao a car which license plate number was 6101 just passed me. another that's in front of me reads 6105 rofl omg dying i need a 6102 now
# ✅ HOÀN TẤT RÀ SOÁT.
